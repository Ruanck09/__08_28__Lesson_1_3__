# %%
import pandas as pd

dataframe1 = pd.read_csv('學生成績單1.csv')
dataframe1.index = dataframe1['姓名']
dataframe2 = dataframe1[['國文','英文','數學','自然','社會']]
#sum = dataframe2.sum(axis=1)
#avg = dataframe2.mean(axis=1)
#dataframe2['總分'] = sum
#dataframe2['平均'] = avg
dataframe2
# Out:
#       國文   英文  數學   自然  社會
# 姓名
# 王德城   81   67  85   69  56
# 王惠皓   85   58  86   67  54
# 陳姵彬   73   50  62   58  86
# 陳淑娟   69   70  52   90  53
# 陳孝邦   94   70  58   91  62
# 彭虹屏   75   58  56   51  51
# 盧文啟   94   59  80   61  77
# 楊韻如   64   53  53   84  83
# 唐雪豪   93   88  86   97  60
# 張凱妮   62   57  88   61  56
# 張凱妮   66   68  93   70  57
# 吳明妮   51   57  89   51  88
# 謝水儒   85   61  55   55  53
# 艾巧夫   76   81  68   90  88
# 張伊映   51   63  51   56  64
# 劉旭士   75   73  91   77  66
# 趙家豪   82   98  89   91  56
# 鄭孟芳   68   79  65   90  75
# 藍哲嘉   74   58  95   93  96
# 吳明妮   77   82  67   56  52
# 洪阿惠   56   69  63  100  81
# 童建霖   97   61  71   98  53
# 趙宛真   62   66  81   81  65
# 陳淑萍   57   93  91   93  65
# 林佳人   52   80  76   70  59
# 林冠蕙   81  100  51   79  73
# 戴萱能   93   67  82   61  97
# 黃必琪   66   73  62   82  96
# 林清英   95   94  73   76  91
# 馮耀中   79   97  58   80  83
# 陳怡容   53   81  77   60  59
# 陳向愛   55   74  98   50  85
# 游一鈺   76   79  97   71  50
# ...

# %%
name1 = dataframe2.loc[['趙家豪']]
name1
# Out:
#      國文  英文  數學  自然  社會
# 姓名
# 趙家豪  82  98  89  91  56

# %%
sum = name1.loc['趙家豪'].sum()
avg = name1.loc['趙家豪'].mean()
name1['總分'] = sum
name1['平均'] = avg
name1
# Out:
#      國文  英文  數學  自然  社會   總分    平均
# 姓名
# 趙家豪  82  98  89  91  56  416  83.2

# %%
sum_s = dataframe2.sum(axis=1)
mean_s = dataframe2.mean(axis=1)
dataframe2['總分'] = sum_s
dataframe2['平均'] = mean_s
dataframe2
# Out:
#       國文   英文  數學   自然  社會   總分    平均
# 姓名
# 王德城   81   67  85   69  56  358  71.6
# 王惠皓   85   58  86   67  54  350  70.0
# 陳姵彬   73   50  62   58  86  329  65.8
# 陳淑娟   69   70  52   90  53  334  66.8
# 陳孝邦   94   70  58   91  62  375  75.0
# 彭虹屏   75   58  56   51  51  291  58.2
# 盧文啟   94   59  80   61  77  371  74.2
# 楊韻如   64   53  53   84  83  337  67.4
# 唐雪豪   93   88  86   97  60  424  84.8
# 張凱妮   62   57  88   61  56  324  64.8
# 張凱妮   66   68  93   70  57  354  70.8
# 吳明妮   51   57  89   51  88  336  67.2
# 謝水儒   85   61  55   55  53  309  61.8
# 艾巧夫   76   81  68   90  88  403  80.6
# 張伊映   51   63  51   56  64  285  57.0
# 劉旭士   75   73  91   77  66  382  76.4
# 趙家豪   82   98  89   91  56  416  83.2
# 鄭孟芳   68   79  65   90  75  377  75.4
# 藍哲嘉   74   58  95   93  96  416  83.2
# 吳明妮   77   82  67   56  52  334  66.8
# 洪阿惠   56   69  63  100  81  369  73.8
# 童建霖   97   61  71   98  53  380  76.0
# 趙宛真   62   66  81   81  65  355  71.0
# ...

# %%
dataframe2.loc[['趙家豪']]
# Out:
#      國文  英文  數學  自然  社會   總分    平均
# 姓名
# 趙家豪  82  98  89  91  56  416  83.2
