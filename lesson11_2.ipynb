# %%
import csv

with open("學生成績單1.csv",encoding="utf-8",newline="") as file:
    dict_reader = csv.DictReader(file)
    students = list(dict_reader)
    for student in students:
        student["國文"] = int(student["國文"])
        student["英文"] = int(student["英文"])
        student["數學"] = int(student["數學"])
        student["自然"] = int(student["自然"])
        student["社會"] = int(student["社會"])

students
# Out:
# [{'姓名': '王德城', '國文': 81, '英文': 67, '數學': 85, '自然': 69, '社會': 56},
#  {'姓名': '王惠皓', '國文': 85, '英文': 58, '數學': 86, '自然': 67, '社會': 54},
#  {'姓名': '陳姵彬', '國文': 73, '英文': 50, '數學': 62, '自然': 58, '社會': 86},
#  {'姓名': '陳淑娟', '國文': 69, '英文': 70, '數學': 52, '自然': 90, '社會': 53},
#  {'姓名': '陳孝邦', '國文': 94, '英文': 70, '數學': 58, '自然': 91, '社會': 62},
#  {'姓名': '彭虹屏', '國文': 75, '英文': 58, '數學': 56, '自然': 51, '社會': 51},
#  {'姓名': '盧文啟', '國文': 94, '英文': 59, '數學': 80, '自然': 61, '社會': 77},
#  {'姓名': '楊韻如', '國文': 64, '英文': 53, '數學': 53, '自然': 84, '社會': 83},
#  {'姓名': '唐雪豪', '國文': 93, '英文': 88, '數學': 86, '自然': 97, '社會': 60},
#  {'姓名': '張凱妮', '國文': 62, '英文': 57, '數學': 88, '自然': 61, '社會': 56},
#  {'姓名': '張凱妮', '國文': 66, '英文': 68, '數學': 93, '自然': 70, '社會': 57},
#  {'姓名': '吳明妮', '國文': 51, '英文': 57, '數學': 89, '自然': 51, '社會': 88},
#  {'姓名': '謝水儒', '國文': 85, '英文': 61, '數學': 55, '自然': 55, '社會': 53},
#  {'姓名': '艾巧夫', '國文': 76, '英文': 81, '數學': 68, '自然': 90, '社會': 88},
# ...

# %%
for stu in students:
    print(stu["姓名"])
    sum = stu["國文"] + stu["英文"] + stu["數學"] + stu["自然"] + stu["社會"]
    print(f"總分:{sum}")
    print(f"平均:{sum/5:.2f}")
    print("=========================")
# Out:
# 王德城
# 總分:358
# 平均:71.60
# ...
# 王惠皓
# 總分:350
# 平均:70.00
# ...
# 陳姵彬
# 總分:329
# 平均:65.80
# ...
# 陳淑娟
# 總分:334
# 平均:66.80
# ...
# 陳孝邦
# 總分:375
# 平均:75.00
# ...
# 彭虹屏
# 總分:291
# 平均:58.20
# ...
# 盧文啟
# 總分:371
# 平均:74.20
# ...
# 楊韻如
# 總分:337
# 平均:67.40
# ...
# 唐雪豪
# 總分:424
# 平均:84.80
# ...
# 張凱妮
# 總分:324
# 平均:64.80
# ...
# 張凱妮
# 總分:354
# 平均:70.80
# ...
# 吳明妮
# 總分:336
# 平均:67.20
# ...
# 謝水儒
# 總分:309
# 平均:61.80
# ...
# 艾巧夫
# 總分:403
# 平均:80.60
# ...
# 張伊映
# 總分:285
# 平均:57.00
# ...
# 劉旭士
# 總分:382
# 平均:76.40
# ...
# 趙家豪
# 總分:416
# 平均:83.20
# ...
# 鄭孟芳
# 總分:377
# 平均:75.40
# ...
# 藍哲嘉
# 總分:416
# 平均:83.20
# ...
# 吳明妮
# 總分:334
# 平均:66.80
# ...
# 洪阿惠
# 總分:369
# 平均:73.80
# ...
# 童建霖
# 總分:380
# 平均:76.00
# ...
# 趙宛真
# 總分:355
# 平均:71.00
# ...
# 陳淑萍
# 總分:399
# 平均:79.80
# ...
# 林佳人
# 總分:337
# 平均:67.40
# ...
# 林冠蕙
# 總分:384
# 平均:76.80
# ...
# 戴萱能
# 總分:400
# 平均:80.00
# ...
# 黃必琪
# 總分:379
# 平均:75.80
# ...
# 林清英
# 總分:429
# 平均:85.80
# ...
# 馮耀中
# 總分:397
# 平均:79.40
# ...
# 陳怡容
# 總分:330
# 平均:66.00
# ...
# 陳向愛
# 總分:362
# 平均:72.40
# ...
# 游一鈺
# 總分:373
# 平均:74.60
# ...
# 林康亮
# 總分:423
# 平均:84.60
# ...
# 蔡至剛
# 總分:363
# 平均:72.60
# ...
# 林士凱
# 總分:387
# 平均:77.40
# ...
# 余宗儒
# 總分:374
# 平均:74.80
# ...
# 盧冠發
# 總分:396
# 平均:79.20
# ...
# 朱彥志
# ...
